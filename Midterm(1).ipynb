# %%
import midterm as p1

# %% [markdown]
# # Phys227 Midterm
#
# ### Taylor Patti
# ### 3/19/16

# %% [markdown]
# ## Problem 1
#
# Below are the Logistic Maps for initial value x = 0.5 and growth parameters of r = 2.5, 3.2, and 3.5 respectively. The first graph (r = 2.5) is well within the exclusive range of r between 1 and 3 which results in population stabalization at a given point, determined by the growth parameter. Regardless of initial condition, the long-term behavior will come to this same pattern. All of these statements are of course dependent on the fact that the growth parameter is between 0 and 1. Negative populations don't exist, zero populations don't reproduce, and a population of 1 would die instantly as 1 corresponds to the carrying-capacity. Likewise, populations of over 1 are also unphysical for this model as they correspond to populations above the carrying capacity.

# %%
p1.graph(0.5, 2.6)

# %% [markdown]
# This second graph shows the same logistic map, but at r = 3.2. This is a sufficiently large growth parameter such that the bifurcation point has been reached. The oscillations have now settled into a two cycle, like a population who surges in growth one year, and then suffers great losses the next due to the perils of over population. Although this pattern is more complicated, this behavior is still oscillatory, and the long-term behavior is not influenced by the initial conditons, but rather, by the growth parameter.

# %%
p1.graph(0.5, 3.2)

# %% [markdown]
# This graph of r = 3.5 has passed the second bifurcation point and now has 4 different cycle points. While this is more complex oscillatory behavior, it is still good and predictable. This pattern is again independent of initial conditions, which is why it's non-chaotic and predictable. To illustrate this further, we include two more plots at this growth parameter with different initial conditions. Although they begin in different manners, these plots sink into the same pattern in the long-term.

# %%
p1.graph(0.5, 3.5)

# %%
p1.graph(0.2, 3.5)

# %%
p1.graph(0.8, 3.5)

# %% [markdown]
# ## Problem 2
#
# At this value of r = 3.5441, our bifurcation has split into 8 different cycle types. Notice that these come in very similar pairs of two, yet there are still 8 distinct values. With only a 4 part bifurcation, initial conditions between 0 and 1 exclusie should still yield the same long term behavior.

# %%
p1.graph(0.5, 3.5441)

# %% [markdown]
# At this value of r = 3.5699, our bifurcation has expanded considerably. Chaos is very near, but there are still distinctive, yet complicated, periodic behavior. We have 14 different cycle values at this point, 3 bands which vary in 4 and one band which varies in two. As we are still in the oscillatory part of this logistic map, different initial conditions within the 0 to 1 exclusive range will still give us the same long term behavior.

# %%
p1.graph(0.5, 3.5699)

# %% [markdown]
# At this value of r = 3.57, we have begun to lose predictable periodic behavior. Just looking at the first graph with the initial conditions of x = 0.5, it is nearly impossible to tell whether we have chaotic behavior or just very complicated oscillatory behavior. However, when we make the other two plots of initial conditions of x = 0.2 and x = 0.8, we see that the long term behavior does not line up, but rather has slight variations. This means that the chaos has begun and initial conditions have begun to manner quite a bit.

# %%
p1.graph(0.5, 3.57)

# %%
p1.graph(0.2, 3.57)

# %%
p1.graph(0.8, 3.57)

# %% [markdown]
# ## Problem 3
#
# In this section we plotted the final 100 of 200 cycle points vs the growth parameter to show how, with growth parameter increasing on the interval from 2.9 to 4, we get more and more cycle points, rapidly approaching a point known as chaos. As no discussion was indicated in this section, further analysis of this phenomena will be saved until the next section, Problem 4.

# %%
p1.big_graph()

# %% [markdown]
# ## Problem 4
#
# Let's evaluate our findings problem by problem, starting with the first one. In Problem 1, we saw the progression through growth parameters of r from 2.5 to 3.5 of one fixed point to a two cycle to a four cycle. While this bifurcation is more complex than the simpler oscillations that we may be typically accostomed to, it actually still represents oscillatory behavior in a more intricate cycle. Moreover, differing initial conditions would still produce the same long term behavior.
#
# In problem 2 we witnessed the gradual descent into chaotic madness. The first two plots had great complexity, yet they were still periodic and independent of initial conditions, while the third broke rank and began to show true chaotic behavior. At this point, initial conditions do matter. This is a trademark of chaotic behavior.
#
# Finally, in problem 3 we essentially formed a plot of number of number of cycle points vs growth parameter. As this graph illustrates, r = 3.57 or so is where chaotic behavior really begins to kick in and the cycle points become increasingly numerous and unpredictable. Another interesting facet of this plot are the regions of relative good behaivior, such as 3.84, where we see just a few cycle points per r value. This is like those damped oscillators that do have some higher drag force periodic modes. Self-symmetry is also apparent. When you examen the small branches, you can see that they look like the big branches. All in all a very fascinating topic chaos is.
#
# I learned some stuff about chaos in Mechanics 2, so when I saw the logistic equation I figured I knew what it was going to do. But, if I had not known of chaos, I bet that I would not have predicted such crazy behavior, because it was an assignment and assignments are usually cute little equations. That being said, if you gave me a random equation, then yes, I would expect it to do wild things, because most real life equations are pretty wild. In order to analyze the behavior of this update map further I would be interested in making comparisons between different initial conditions. I would also be interested in examining the transition between one cycle point and a bifurcation more closely.
